# %% [markdown]
# # Lecture 01: Course Introduction and Git - Verify Setup
#
# In Jupyter Notebook, you can not only run python code, but also run shell commands by prefixing them with an exclamation mark (!).

# %% [markdown]
# ### Verify your python installation

# %%
# !python --version

# %% [markdown]
# ### Verify your uv installation

# %%
# !uv --version

# %% [markdown]
# ### Git and Shell commands

# %%
# !git --version

# %%
# !git status

# %%
# show the contents of the current directory
# !ls ../ -a

# %% [markdown]
# ### Install a few packages

# %%
# !uv pip install numpy pandas matplotlib

# %%
# and list the installed packages
# !uv pip list

# %% [markdown]
# ### Hello World in Python

# %%
print("Hello World!")

# %% [markdown]
# ### Import and use a package

# %%
import numpy as np
a = np.array([1, 2, 3])
print(a)

# %% [markdown]
# ### Jupyter notebooks are great for plotting data
# $\rightarrow$ you will see more of this in the next lecture

# %%
from matplotlib import pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
